# %% [markdown]
# # scratchpad

# %% [markdown]
# ## Generating latex tables

# %%
import pickle
import sys
import re
import os

sys.path.append("../")

from src.presentation import LatexPrettyPrinter

home = os.environ.get("HOME")

dataDir = "/home/myc0plasmus/Documents/studia/heuristicResults/" 

resultList = [
    "results_componentProportionDistribution_6e3e3a9d-4abf-445a-b887-d5eaf9ee15af",
    "results_componentSizeDistribution_e7031d3d-c12d-454e-9c36-2d856eb4a843",
    "results_degreeDistribution_3e402735-6b9c-492f-abdb-6205f1caca28",
    "results_proportionCountDistribution_53a87b52-22d8-4850-956d-67beb45c7f17"
]



networkPaths = [
    'network_componentProportionDistribution_covid_1 vs covid_2_covid_1_6e3e3a9d-4abf-445a-b887-d5eaf9ee15af.csv',
    'network_componentProportionDistribution_covid_1 vs covid_2_covid_2_6e3e3a9d-4abf-445a-b887-d5eaf9ee15af.csv',
    'network_componentProportionDistribution_healthy_1 vs healthy_2_healthy_1_6e3e3a9d-4abf-445a-b887-d5eaf9ee15af.csv',
    'network_componentProportionDistribution_healthy_1 vs healthy_2_healthy_2_6e3e3a9d-4abf-445a-b887-d5eaf9ee15af.csv',
    'network_componentProportionDistribution_healthy vs covid_covid_6e3e3a9d-4abf-445a-b887-d5eaf9ee15af.csv',
    'network_componentProportionDistribution_healthy vs covid_healthy_6e3e3a9d-4abf-445a-b887-d5eaf9ee15af.csv',
    'network_componentSizeDistribution_covid_1 vs covid_2_covid_1_e7031d3d-c12d-454e-9c36-2d856eb4a843.csv',
    'network_componentSizeDistribution_covid_1 vs covid_2_covid_2_e7031d3d-c12d-454e-9c36-2d856eb4a843.csv',
    'network_componentSizeDistribution_healthy_1 vs healthy_2_healthy_1_e7031d3d-c12d-454e-9c36-2d856eb4a843.csv',
    'network_componentSizeDistribution_healthy_1 vs healthy_2_healthy_2_e7031d3d-c12d-454e-9c36-2d856eb4a843.csv',
    'network_componentSizeDistribution_healthy vs covid_covid_e7031d3d-c12d-454e-9c36-2d856eb4a843.csv',
    'network_componentSizeDistribution_healthy vs covid_healthy_e7031d3d-c12d-454e-9c36-2d856eb4a843.csv',
    'network_degreeDistribution_covid_1 vs covid_2_covid_1_3e402735-6b9c-492f-abdb-6205f1caca28.csv',
    'network_degreeDistribution_covid_1 vs covid_2_covid_2_3e402735-6b9c-492f-abdb-6205f1caca28.csv',
    'network_degreeDistribution_healthy_1 vs healthy_2_healthy_1_3e402735-6b9c-492f-abdb-6205f1caca28.csv',
    'network_degreeDistribution_healthy_1 vs healthy_2_healthy_2_3e402735-6b9c-492f-abdb-6205f1caca28.csv',
    'network_degreeDistribution_healthy vs covid_covid_3e402735-6b9c-492f-abdb-6205f1caca28.csv',
    'network_degreeDistribution_healthy vs covid_healthy_3e402735-6b9c-492f-abdb-6205f1caca28.csv',
    'network_proportionCountDistribution_covid_1 vs covid_2_covid_1_53a87b52-22d8-4850-956d-67beb45c7f17.csv',
    'network_proportionCountDistribution_covid_1 vs covid_2_covid_2_53a87b52-22d8-4850-956d-67beb45c7f17.csv',
    'network_proportionCountDistribution_healthy_1 vs healthy_2_healthy_1_53a87b52-22d8-4850-956d-67beb45c7f17.csv',
    'network_proportionCountDistribution_healthy_1 vs healthy_2_healthy_2_53a87b52-22d8-4850-956d-67beb45c7f17.csv',
    'network_proportionCountDistribution_healthy vs covid_covid_53a87b52-22d8-4850-956d-67beb45c7f17.csv',
    'network_proportionCountDistribution_healthy vs covid_healthy_53a87b52-22d8-4850-956d-67beb45c7f17.csv',
]

allNetworks = {}

groups = [
    'healthy vs covid',
    'covid_1 vs covid_2',
    'healthy_1 vs healthy_2'
]

for networkFilename in networkPaths:
    networkPath = dataDir + networkFilename
    splitFilename = networkFilename.split("_")
    distributionName = splitFilename[1]
    group = "dummy"
    for checked_group in groups:
        if re.search(checked_group, networkFilename):
            group = checked_group
            break

    networkGroup = splitFilename[-2] if not splitFilename[-2] in ["1","2"] else (splitFilename[-3] + "_" + splitFilename[-2])

    if not distributionName in allNetworks:
        allNetworks[distributionName] = {}
    if not group in allNetworks[distributionName]:
        allNetworks[distributionName][group] = {} 
    with open(networkPath, "rb") as f:
        allNetworks[distributionName][group][networkGroup] = pickle.load(f)

# print(allNetworks)

distributionNameDict = {
    "degreeDistribution": "rozkładu stopni wierzchołków",
    "componentSizeDistribution": "rozkładu rozmiaru komponentów",
    "proportionCountDistribution": "rozkładu proporcji wierzchołków",
    "componentProportionDistribution": "rozkładu proporcji komponentów",
 
}
    
for resultFilename in resultList:
    resultPath = dataDir + resultFilename
    with open(resultPath, "rb") as f:
        result = pickle.load(f)
    result = { resname:result[resname] for resname in result if resname != "universal"}
    distributionName = resultFilename.split("_")[1]

    LatexPrettyPrinter().printTable(result, allNetworks[distributionName], distributionNameDict[distributionName])
# Out:
# Tabele dla rozkładu proporcji komponentów
# \vspace{1em}
# Tabele opisujące parametry tworzenia sieci znalezione przez heurystykę
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|}
# \hline
# Grupa testowa & Najlepszy wynik & Funckja dystansu & Próg podobieństwa \\
# \hline
# healthy vs covid & 1.00 & alignment & 0.33 \\
# \hline
# covid_1 vs covid_2 & 1.00 & alignment & 0.20 \\
# \hline
# healthy_1 vs healthy_2 & 0.92 & alignment & 0.25 \\
# \hline
# \end{tabular}
#
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Macierz podstawień & Nazwa algorytmu \\
# \hline
# healthy vs covid & BLOSUM45 & simpleVectorBetaDistance \\
# \hline
# covid_1 vs covid_2 & PAM70 & simpleVectorBetaDistance \\
# \hline
# healthy_1 vs healthy_2 & BLOSUM90 & simpleVectorBetaDistance \\
# \hline
# \end{tabular}
#
# \vspace{1em}
# Tabele porównujące sieci wygenerowane na podstawie parametrów dla różnych grup
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Proporcja izolowanych wierzchołków & Gęstość krawędzi & Gęstość \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 0.02 & 0.44 & 0.43 \\
# \cline{2-5}
#   & covid & 0.08 & 0.50 & 0.42 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 0.09 & 0.25 & 0.21 \\
# \cline{2-5}
#   & covid\_2 & 0.58 & 0.14 & 0.05 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 0.02 & 0.21 & 0.20 \\
# \cline{2-5}
#   & healthy\_2 & 0.04 & 0.28 & 0.25 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Ekscentryczność & Wielki komponent & Średni stopień \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 3.00 & 5116.00 & 2228.31 \\
# \cline{2-5}
#   & covid & 1.00 & 5459.00 & 2509.30 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 5.00 & 5455.00 & 1272.74 \\
# \cline{2-5}
#   & covid\_2 & 4.00 & 31.00 & 2.57 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 4.00 & 5112.00 & 1047.40 \\
# \cline{2-5}
#   & healthy\_2 & 4.00 & 2736.00 & 721.40 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Liczka komponentów \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 92.00 \\
# \cline{2-3}
#   & covid & 463.00 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 469.00 \\
# \cline{2-3}
#   & covid\_2 & 19.00 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 96.00 \\
# \cline{2-3}
#   & healthy\_2 & 119.00 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \vspace{1em}
#
# Tabele dla rozkładu rozmiaru komponentów
# \vspace{1em}
# Tabele opisujące parametry tworzenia sieci znalezione przez heurystykę
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|}
# \hline
# Grupa testowa & Najlepszy wynik & Funckja dystansu & Próg podobieństwa \\
# \hline
# healthy vs covid & 1.00 & alignment & 0.40 \\
# \hline
# covid_1 vs covid_2 & 1.00 & alignment & 0.40 \\
# \hline
# healthy_1 vs healthy_2 & 1.00 & alignment & 0.24 \\
# \hline
# \end{tabular}
#
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Macierz podstawień & Nazwa algorytmu \\
# \hline
# healthy vs covid & BLOSUM62 & simpleVectorBetaDistance \\
# \hline
# covid_1 vs covid_2 & PAM70 & simpleBetaDistance \\
# \hline
# healthy_1 vs healthy_2 & BLOSUM90 & simpleVectorBetaDistance \\
# \hline
# \end{tabular}
#
# \vspace{1em}
# Tabele porównujące sieci wygenerowane na podstawie parametrów dla różnych grup
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Proporcja izolowanych wierzchołków & Gęstość krawędzi & Gęstość \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 0.03 & 0.57 & 0.54 \\
# \cline{2-5}
#   & covid & 0.06 & 0.61 & 0.54 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 2.30 & 0.03 & 0.00 \\
# \cline{2-5}
#   & covid\_2 & 2.15 & 0.03 & 0.00 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 0.03 & 0.19 & 0.18 \\
# \cline{2-5}
#   & healthy\_2 & 0.02 & 0.18 & 0.17 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Ekscentryczność & Wielki komponent & Średni stopień \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 3.00 & 5953.00 & 3304.29 \\
# \cline{2-5}
#   & covid & 3.00 & 356.00 & 203.35 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 1.00 & 84.00 & 0.87 \\
# \cline{2-5}
#   & covid\_2 & 1.00 & 66.00 & 0.96 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 1.00 & 5949.00 & 1116.99 \\
# \cline{2-5}
#   & healthy\_2 & 4.00 & 5126.00 & 892.81 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Liczka komponentów \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 157.00 \\
# \cline{2-3}
#   & covid & 24.00 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 278.00 \\
# \cline{2-3}
#   & covid\_2 & 206.00 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 160.00 \\
# \cline{2-3}
#   & healthy\_2 & 97.00 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \vspace{1em}
#
# Tabele dla rozkładu stopni wierzchołków
# \vspace{1em}
# Tabele opisujące parametry tworzenia sieci znalezione przez heurystykę
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|}
# \hline
# Grupa testowa & Najlepszy wynik & Funckja dystansu & Próg podobieństwa \\
# \hline
# healthy vs covid & 0.69 & alignment & 0.29 \\
# \hline
# covid_1 vs covid_2 & 1.00 & alignment & 0.29 \\
# \hline
# healthy_1 vs healthy_2 & 1.00 & alignment & 0.22 \\
# \hline
# \end{tabular}
#
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Macierz podstawień & Nazwa algorytmu \\
# \hline
# healthy vs covid & PAM70 & simpleBetaDistance \\
# \hline
# covid_1 vs covid_2 & BLOSUM80 & simpleBetaDistance \\
# \hline
# healthy_1 vs healthy_2 & PAM30 & simpleBetaDistance \\
# \hline
# \end{tabular}
#
# \vspace{1em}
# Tabele porównujące sieci wygenerowane na podstawie parametrów dla różnych grup
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Proporcja izolowanych wierzchołków & Gęstość krawędzi & Gęstość \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 1.17 & 0.00 & 0.00 \\
# \cline{2-5}
#   & covid & 28.50 & 0.33 & 0.00 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 10.80 & 0.11 & 0.00 \\
# \cline{2-5}
#   & covid\_2 & 1.50 & 0.00 & 0.00 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 6.19 & 0.00 & 0.00 \\
# \cline{2-5}
#   & healthy\_2 & 6.93 & 0.00 & 0.00 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Ekscentryczność & Wielki komponent & Średni stopień \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 1.00 & 1031.00 & 1.97 \\
# \cline{2-5}
#   & covid & 1.00 & 2.00 & 0.03 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 1.00 & 2.00 & 0.08 \\
# \cline{2-5}
#   & covid\_2 & 1.00 & 1815.00 & 3.19 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 1.00 & 19.00 & 0.21 \\
# \cline{2-5}
#   & healthy\_2 & 1.00 & 22.00 & 0.19 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Liczka komponentów \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 2127.00 \\
# \cline{2-3}
#   & covid & 116.00 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 113.00 \\
# \cline{2-3}
#   & covid\_2 & 3686.00 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 3389.00 \\
# \cline{2-3}
#   & healthy\_2 & 3507.00 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \vspace{1em}
#
# Tabele dla rozkładu proporcji wierzchołków
# \vspace{1em}
# Tabele opisujące parametry tworzenia sieci znalezione przez heurystykę
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|}
# \hline
# Grupa testowa & Najlepszy wynik & Funckja dystansu & Próg podobieństwa \\
# \hline
# healthy vs covid & 1.00 & alignment & 0.32 \\
# \hline
# covid_1 vs covid_2 & 1.00 & alignment & 0.32 \\
# \hline
# healthy_1 vs healthy_2 & 1.00 & alignment & 0.29 \\
# \hline
# \end{tabular}
#
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Macierz podstawień & Nazwa algorytmu \\
# \hline
# healthy vs covid & BLOSUM62 & simpleVectorBetaDistance \\
# \hline
# covid_1 vs covid_2 & BLOSUM62 & simpleVectorBetaDistance \\
# \hline
# healthy_1 vs healthy_2 & BLOSUM90 & simpleBetaDistance \\
# \hline
# \end{tabular}
#
# \vspace{1em}
# Tabele porównujące sieci wygenerowane na podstawie parametrów dla różnych grup
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Proporcja izolowanych wierzchołków & Gęstość krawędzi & Gęstość \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 0.04 & 0.45 & 0.41 \\
# \cline{2-5}
#   & covid & 0.03 & 0.47 & 0.44 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 0.03 & 0.48 & 0.45 \\
# \cline{2-5}
#   & covid\_2 & 0.04 & 0.41 & 0.38 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 1.34 & 0.00 & 0.00 \\
# \cline{2-5}
#   & healthy\_2 & 0.75 & 0.00 & 0.00 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Ekscentryczność & Wielki komponent & Średni stopień \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 4.00 & 2740.00 & 1170.95 \\
# \cline{2-5}
#   & covid & 1.00 & 526.00 & 242.31 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 1.00 & 526.00 & 246.18 \\
# \cline{2-5}
#   & covid\_2 & 3.00 & 1451.00 & 576.96 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 1.00 & 833.00 & 1.75 \\
# \cline{2-5}
#   & healthy\_2 & 1.00 & 1980.00 & 3.84 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \noindent
# \begin{tabular}{|c|c|c|}
# \hline
# Grupa testowa & Grupa sieci & Liczka komponentów \\
# \hline
# \multirow{2}{*}{healthy vs covid} & healthy & 115.00 \\
# \cline{2-3}
#   & covid & 21.00 \\
# \hline
# \multirow{2}{*}{covid\_1 vs covid\_2} & covid\_1 & 21.00 \\
# \cline{2-3}
#   & covid\_2 & 62.00 \\
# \hline
# \multirow{2}{*}{healthy\_1 vs healthy\_2} & healthy\_1 & 1733.00 \\
# \cline{2-3}
#   & healthy\_2 & 2335.00 \\
# \hline
# \end{tabular}
# \vspace{1em}
#
# \vspace{1em}

# %%
from src.analysis.visualization.multiGraphChart import multiGraphChart
from tqdm import tqdm

for distributionName in allNetworks:
    print(f"Calculating graphs for {distributionName}")
    for test_group in tqdm(allNetworks[distributionName]):
        networksDict = allNetworks[distributionName][test_group]
        plotTitles = [ f"Sieć próbki {group} dla {distributionNameDict[distributionName]}" for group in networksDict] 
        networks = [ networksDict[group] for group in networksDict ]
        multiGraphChart(plotTitles, networks, f"{distributionName}_{test_group}.png")
# Out:
# Calculating graphs for componentProportionDistribution
#   0%|                                                                                                                                                                                                                                             | 0/3 [00:00<?, ?it/s]
